# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.fontset"] = "stix"

import pickle  # noqa: S403
from pathlib import Path

import evaluation as ev

# %% [markdown]
# ### $q=24$ and 50 different circuits per data point for variation in number of factories and reset time

# %%
path = "./f_vs_time_q24_ratio08_small_row_250718_2_8_f_t_temp"

with Path(path).open("rb") as f:
    res_lst = pickle.load(f)  # noqa: S301

path = "./f_vs_time_q24_ratio08_small_row_250718_2_8_f_t_temp_metricrouting"

with Path(path).open("rb") as f:
    res_lst_routing = pickle.load(f)  # noqa: S301

# %%
len(res_lst_routing[0]["circuits"])
# Out:
# 50

# %%
hc_params = res_lst[0]["hc_params"]
size = (3.9, 3.9)
ev.plot_f_vs_t_subfigs(res_lst, res_lst_routing, 24, 0.8, "row", 96, "CC", hc_params, size=size, path="")
# Out:
# /mnt/c/Users/Laura/Documents/Codes_and_Repos/cococo/scripts/evaluations_beyond_the_surface_code/evaluation.py:1710: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])

# %% [markdown]
# ### Compare different circuit types and layouts for 50 sampled circuits per data point

# %%
path = "./circuit_types_q24_250718_c"
with Path(path).open("rb") as f:
    res_lst = pickle.load(f)  # noqa: S301

# %%
len(res_lst[0]["circuits"])
# Out:
# 50

# %%
size = (4.5, 2.5)
ev.plot_improvement_circuit_types(res_lst, size=size, path="")
